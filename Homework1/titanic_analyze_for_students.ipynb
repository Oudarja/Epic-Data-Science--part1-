# %% [markdown]
# Dear students, in this homework, you will analyze the Titanic dataset. Please read the tasks carefully and ask any questions you have on Discord. The homework consists of 10 tasks with a total of 10 points, but bonus points may be awarded for accuracy in task 10. Good luck and have fun!

# %%
import pandas as pd

# %% [markdown]
# ##Task 1. Read the data and display top 5 rows(0.5 pt)

# %%
df=pd.read_csv("train__2_.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ##Task 2. Print dataframe's columns names and dimensionality(0.5 pt)

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ##Task 3. Calculate how many men and women are in the dataset (0.5 pt)

# %%
ml=0
fm=0

for value in df['Sex']:
    if value=='male':
        ml=ml+1
    else:
        fm=fm+1;

print("No of Male: ",ml)
print("No of Female: ",fm)
# Out:
# No of Male:  577
# No of Female:  314

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# #Task 4. Calculate survival rate for men and women (0.5 pt)

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
mls=0
fms=0

for value1,value in zip(df['Sex'],df['Survived']):
    if value1=='male' and value==1:
        mls=mls+1
    elif value1=='female' and value==1:
        fms=fms+1

print("Men's survival rate",mls/342)

print("Women's survival rate", fms/342)
# Out:
# Men's survival rate 0.31871345029239767
# Women's survival rate 0.6812865497076024

# %% [markdown]
# #Task 5. Group the data by Pclass and and display statistics on Age and Fare (1 pt)

# %%
grouped_df=df.groupby('Pclass').agg({'Age':['mean','median','min','max'],'Fare':['mean','median','min','max']})

# %%
grouped_df
# Out:
#               Age                          Fare
#              mean median   min   max       mean   median  min       max
# Pclass
# 1       38.233441   37.0  0.92  80.0  84.154687  60.2875  0.0  512.3292
# 2       29.877630   29.0  0.67  70.0  20.662183  14.2500  0.0   73.5000
# 3       25.140620   24.0  0.42  74.0  13.675550   8.0500  0.0   69.5500

# %% [markdown]
# #Task 6. What is the most popular family name in the dataset (1 pt)

# %% [markdown]
# ##Task 7. What is the mean and std for all columns for survived male passengers (1 pt)

# %%
#df.describe()
filtered_df=df[(df['Sex']=='male')&(df['Survived']==1)]

# %%
filtered_df
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
filtered_df.describe()
# Out:
#        PassengerId  Survived      Pclass        Age       SibSp       Parch  \
# count   109.000000     109.0  109.000000  93.000000  109.000000  109.000000
# mean    475.724771       1.0    2.018349  27.276022    0.385321    0.357798
# std     244.717482       0.0    0.922774  16.504803    0.636952    0.645826
# min      18.000000       1.0    1.000000   0.420000    0.000000    0.000000
# 25%     272.000000       1.0    1.000000  18.000000    0.000000    0.000000
# 50%     508.000000       1.0    2.000000  28.000000    0.000000    0.000000
# 75%     680.000000       1.0    3.000000  36.000000    1.000000    1.000000
# max     890.000000       1.0    3.000000  80.000000    4.000000    2.000000
#
#              Fare
# count  109.000000
# mean    40.821484
# std     71.355967
# min      0.000000
# 25%      9.500000
# 50%     26.287500
# 75%     39.000000
# max    512.329200

# %% [markdown]
# #Task 8. Display rows from 40th to 60th (in numeration from zero) (1 pt)

# %%
df[40:61]
# Out:
#     PassengerId  Survived  Pclass  \
# 40           41         0       3
# 41           42         0       2
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
# 50           51         0       3
# 51           52         0       3
# 52           53         1       1
# 53           54         1       2
# 54           55         0       1
# 55           56         1       1
# 56           57         1       2
# 57           58         0       3
# 58           59         1       2
# 59           60         0       3
# 60           61         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ...

# %% [markdown]
# ##Task 9. Sort the table by Fare in descending order (1 pt)

# %%
sorted_df = df.sort_values(by='Fare', ascending=False)

# Display the sorted dataframe
sorted_df
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %% [markdown]
# ##Task 10 Implement simple model to predict whether the person have survived according to knowledge you got from data analysis. Then calculate accuracy of your predictions on the dataset. Try to maximize accuracy (a student with maximum accuracy will recieve additional points). For example, the simplest model may look like (df["predict_survived"] = df["Sex"] == "male") (3 pt)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df=df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Embarked'],axis='columns')

# %%
df
# Out:
#      Survived  Pclass     Sex   Age     Fare Cabin
# 0           0       3    male  22.0   7.2500   NaN
# 1           1       1  female  38.0  71.2833   C85
# 2           1       3  female  26.0   7.9250   NaN
# 3           1       1  female  35.0  53.1000  C123
# 4           0       3    male  35.0   8.0500   NaN
# ..        ...     ...     ...   ...      ...   ...
# 886         0       2    male  27.0  13.0000   NaN
# 887         1       1  female  19.0  30.0000   B42
# 888         0       3  female   NaN  23.4500   NaN
# 889         1       1    male  26.0  30.0000  C148
# 890         0       3    male  32.0   7.7500   NaN
#
# [891 rows x 6 columns]

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
#Filling with first most frequent value to null value
df['Cabin']=df['Cabin'].fillna(df['Cabin'].mode()[0])

# %%
unique_cabin=df['Cabin'].unique()

# %%
len(unique_cabin)
#So one cabin consists of many people that could be the case
# Out:
# 147

# %%
from sklearn.preprocessing import OneHotEncoder
cat_columns=['Sex']
#creating one hot encoder object
encoder = OneHotEncoder(handle_unknown='ignore')

# %%
# Fit the encoder to the categorical columns
encoder.fit(df[cat_columns])
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
feature_names = encoder.get_feature_names_out(input_features=cat_columns)

# %%
print(feature_names)
# Out:
# ['Sex_female' 'Sex_male']

# %%
encoded_cols = encoder.transform(df[cat_columns]).toarray()

# %%
encoded_df = pd.DataFrame(encoded_cols, columns=encoder.get_feature_names_out(input_features=cat_columns))

# Concatenate the encoded dataframe with the original dataframe
final_df = pd.concat([df, encoded_df], axis=1)

# %%
final_df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare    Cabin  Sex_female  Sex_male
# 0         0       3    male  22.0   7.2500  B96 B98         0.0       1.0
# 1         1       1  female  38.0  71.2833      C85         1.0       0.0
# 2         1       3  female  26.0   7.9250  B96 B98         1.0       0.0
# 3         1       1  female  35.0  53.1000     C123         1.0       0.0
# 4         0       3    male  35.0   8.0500  B96 B98         0.0       1.0

# %%
final_df=final_df.drop(['Sex','Sex_female'],axis='columns')

# %%
final_df = final_df.rename(columns={'Sex_male': 'Sex'})

# %%
final_df.head()
# Out:
#    Survived  Pclass   Age     Fare    Cabin  Sex
# 0         0       3  22.0   7.2500  B96 B98  1.0
# 1         1       1  38.0  71.2833      C85  0.0
# 2         1       3  26.0   7.9250  B96 B98  0.0
# 3         1       1  35.0  53.1000     C123  0.0
# 4         0       3  35.0   8.0500  B96 B98  1.0

# %%
#Using label encoder assign different numeric value to different cabin 
from sklearn.preprocessing import LabelEncoder
# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Encode the 'Cabin' column with numeric values
final_df['Cabin'] = label_encoder.fit_transform(final_df['Cabin'].astype(str))

# Display the updated DataFrame
final_df.head()
# Out:
#    Survived  Pclass   Age     Fare  Cabin  Sex
# 0         0       3  22.0   7.2500     47  1.0
# 1         1       1  38.0  71.2833     81  0.0
# 2         1       3  26.0   7.9250     47  0.0
# 3         1       1  35.0  53.1000     55  0.0
# 4         0       3  35.0   8.0500     47  1.0

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
Columns = ['Age','Fare','Cabin']
# Create a MinMaxScaler object
scaler = MinMaxScaler()
# Fit the scaler to the data and transform it
final_df[Columns] = scaler.fit_transform(final_df[Columns])
# Print the normalized dataset
final_df.head()
# Out:
#    Survived  Pclass       Age      Fare     Cabin  Sex
# 0         0       3  0.271174  0.014151  0.321918  1.0
# 1         1       1  0.472229  0.139136  0.554795  0.0
# 2         1       3  0.321438  0.015469  0.321918  0.0
# 3         1       1  0.434531  0.103644  0.376712  0.0
# 4         0       3  0.434531  0.015713  0.321918  1.0

# %%
X=final_df[['Pclass','Age','Fare','Cabin','Sex']]
#featers=['Pclass','Age','Fare','Cabin','Sex']
#or X=final_df[featers]

Y=final_df['Survived']

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# Train the model on the training set
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions on the testing set
y_pred = model.predict(X_test)
# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8100558659217877
